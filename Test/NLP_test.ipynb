# %%
text = """

In the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns. Known for his innovative tactics and leadership, Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats.

Shivaji Maharaj’s stronghold was the Raigad Fort, a formidable fortress perched high on a hilltop. The fort's strategic location allowed him to oversee the surrounding lands and defend against invaders. His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.

The evenings in Shivaji Maharaj's court were vibrant with activity. He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories. During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire. His leadership inspired loyalty and courage among his subjects.

As night fell, Shivaji Maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead. His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.

"""

# %% [markdown]
# ## **Tokenization (3 marks)**
#    a. Tokenize the story into sentences.
#    b. Tokenize the story into words.

# %%
# Tokenizing story into sentences

import nltk

sentences = nltk.sent_tokenize(text)

for sentence in sentences:
    print(sentence)
# Out:
# In the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns.
# Known for his innovative tactics and leadership, Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats.
# Shivaji Maharaj’s stronghold was the Raigad Fort, a formidable fortress perched high on a hilltop.
# The fort's strategic location allowed him to oversee the surrounding lands and defend against invaders.
# His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.
# The evenings in Shivaji Maharaj's court were vibrant with activity.
# He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories.
# During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire.
# His leadership inspired loyalty and courage among his subjects.
# As night fell, Shivaji Maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead.
# His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.

# %%
words_tokens = nltk.word_tokenize(text)
print(words_tokens)
# Out:
# ['In', 'the', 'rugged', 'terrain', 'of', 'the', 'Western', 'Ghats', ',', 'Shivaji', 'Maharaj', ',', 'the', 'founder', 'of', 'the', 'Maratha', 'Empire', ',', 'was', 'preparing', 'for', 'another', 'day', 'of', 'strategic', 'planning', 'and', 'military', 'campaigns', '.', 'Known', 'for', 'his', 'innovative', 'tactics', 'and', 'leadership', ',', 'Shivaji', 'Maharaj', 'was', 'determined', 'to', 'strengthen', 'his', 'kingdom', 'and', 'protect', 'his', 'people', 'from', 'external', 'threats', '.', 'Shivaji', 'Maharaj', '’', 's', 'stronghold', 'was', 'the', 'Raigad', 'Fort', ',', 'a', 'formidable', 'fortress', 'perched', 'high', 'on', 'a', 'hilltop', '.', 'The', 'fort', "'s", 'strategic', 'location', 'allowed', 'him', 'to', 'oversee', 'the', 'surrounding', 'lands', 'and', 'defend', 'against', 'invaders', '.', 'His', 'trusted', 'advisors', 'and', 'generals', 'would', 'gather', 'in', 'the', 'fort', "'s", 'grand', 'hall', 'to', 'discuss', 'plans', ',', 'share', 'intelligence', ',', 'and', 'make', 'critical', 'decisions', 'for', 'the', 'empire', "'s", 'expansion', '.', 'The', 'evenings', 'in', 'Shivaji', 'Maharaj', "'s", 'court', 'were', 'vibrant', 'with', 'activity', '.', 'He', 'would', 'host', 'feasts', 'and', 'gatherings', 'to', 'bolster', 'the', 'morale', 'of', 'his', 'soldiers', 'and', 'celebrate', 'victories', '.', 'During', 'these', 'events', ',', 'Shivaji', 'Maharaj', 'would', 'address', 'his', 'people', ',', 'sharing', 'his', 'vision', 'for', 'a', 'prosperous', 'and', 'united', 'Maratha', 'Empire', '.', 'His', 'leadership', 'inspired', 'loyalty', 'and', 'courage', 'among', 'his', 'subjects', '.', 'As', 'night', 'fell', ',', 'Shivaji', 'Maharaj', 'would', 'retire', 'to', 'his', 'quarters', ',', 'reflecting', 'on', 'the', 'day', "'s", 'achievements', 'and', 'preparing', 'for', 'the', 'challenges', 'ahead', '.', 'His', 'dreams', 'were', 'filled', 'with', 'visions', 'of', 'a', 'strong', 'and', 'resilient', 'empire', ',', 'where', 'justice', 'and', 'valor', 'would', 'prevail', '.']

# %% [markdown]
# ## **Lowercasing (3 marks)**
#    Convert all words in the story to lowercase. Provide the transformed text.

# %%
lower_case = text.lower()
print(lower_case)
# Out:
# in the rugged terrain of the western ghats, shivaji maharaj, the founder of the maratha empire, was preparing for another day of strategic planning and military campaigns. known for his innovative tactics and leadership, shivaji maharaj was determined to strengthen his kingdom and protect his people from external threats.
#
# shivaji maharaj’s stronghold was the raigad fort, a formidable fortress perched high on a hilltop. the fort's strategic location allowed him to oversee the surrounding lands and defend against invaders. his trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.
#
# the evenings in shivaji maharaj's court were vibrant with activity. he would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories. during these events, shivaji maharaj would address his people, sharing his vision for a prosperous and united maratha empire. his leadership inspired loyalty and courage among his subjects.
#
# as night fell, shivaji maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead. his dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.

# %% [markdown]
# ## **Stopword Removal (3 marks)**
#    a. Remove common stopwords (e.g., 'the', 'was', 'a') from the story.
#    b. List the removed stopwords.

# %%
# importing important libraries
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/shiv/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/shiv/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def remove_sw(txt):
    stop_words = set(stopwords.words('english'))
    words_token = word_tokenize(txt)
    clean_text = [words for words in words_token if words not in string.punctuation]
    removed_stopwords = [words for words in clean_text if words not in stop_words]
    return removed_stopwords

print(remove_sw(text))
# Out:
# ['In', 'rugged', 'terrain', 'Western', 'Ghats', 'Shivaji', 'Maharaj', 'founder', 'Maratha', 'Empire', 'preparing', 'another', 'day', 'strategic', 'planning', 'military', 'campaigns', 'Known', 'innovative', 'tactics', 'leadership', 'Shivaji', 'Maharaj', 'determined', 'strengthen', 'kingdom', 'protect', 'people', 'external', 'threats', 'Shivaji', 'Maharaj', '’', 'stronghold', 'Raigad', 'Fort', 'formidable', 'fortress', 'perched', 'high', 'hilltop', 'The', 'fort', "'s", 'strategic', 'location', 'allowed', 'oversee', 'surrounding', 'lands', 'defend', 'invaders', 'His', 'trusted', 'advisors', 'generals', 'would', 'gather', 'fort', "'s", 'grand', 'hall', 'discuss', 'plans', 'share', 'intelligence', 'make', 'critical', 'decisions', 'empire', "'s", 'expansion', 'The', 'evenings', 'Shivaji', 'Maharaj', "'s", 'court', 'vibrant', 'activity', 'He', 'would', 'host', 'feasts', 'gatherings', 'bolster', 'morale', 'soldiers', 'celebrate', 'victories', 'During', 'events', 'Shivaji', 'Maharaj', 'would', 'address', 'people', 'sharing', 'vision', 'prosperous', 'united', 'Maratha', 'Empire', 'His', 'leadership', 'inspired', 'loyalty', 'courage', 'among', 'subjects', 'As', 'night', 'fell', 'Shivaji', 'Maharaj', 'would', 'retire', 'quarters', 'reflecting', 'day', "'s", 'achievements', 'preparing', 'challenges', 'ahead', 'His', 'dreams', 'filled', 'visions', 'strong', 'resilient', 'empire', 'justice', 'valor', 'would', 'prevail']

# %%
def sw_are(txt):
    stop_words = set(stopwords.words('english'))
    words_token = word_tokenize(txt)
    stopwords_are = [words for words in words_token if words in stop_words]
    return stopwords_are

print(sw_are(text))
# Out:
# ['the', 'of', 'the', 'the', 'of', 'the', 'was', 'for', 'of', 'and', 'for', 'his', 'and', 'was', 'to', 'his', 'and', 'his', 'from', 's', 'was', 'the', 'a', 'on', 'a', 'him', 'to', 'the', 'and', 'against', 'and', 'in', 'the', 'to', 'and', 'for', 'the', 'in', 'were', 'with', 'and', 'to', 'the', 'of', 'his', 'and', 'these', 'his', 'his', 'for', 'a', 'and', 'and', 'his', 'to', 'his', 'on', 'the', 'and', 'for', 'the', 'were', 'with', 'of', 'a', 'and', 'where', 'and']

# %% [markdown]
# ## **Punctuation Removal (3 marks)**
#    Remove all punctuation marks from the story. Provide the cleaned text.

# %%
# defing a function to remove the punctuations
def remove_punctuation(txt):
    translator = str.maketrans('', '', string.punctuation)
    return txt.translate(translator)

remove_punctuation(text)
# Out:
# '\n\nIn the rugged terrain of the Western Ghats Shivaji Maharaj the founder of the Maratha Empire was preparing for another day of strategic planning and military campaigns Known for his innovative tactics and leadership Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats\n\nShivaji Maharaj’s stronghold was the Raigad Fort a formidable fortress perched high on a hilltop The forts strategic location allowed him to oversee the surrounding lands and defend against invaders His trusted advisors and generals would gather in the forts grand hall to discuss plans share intelligence and make critical decisions for the empires expansion\n\nThe evenings in Shivaji Maharajs court were vibrant with activity He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories During these events Shivaji Maharaj would address his people sharing his vision for a prosperous and united Maratha Empire His leadership inspired loyalty and courage among his subjects\n\nAs night fell Shivaji Maharaj would retire to his quarters reflecting on the days achievements and preparing for the challenges ahead His dreams were filled with visions of a strong and resilient empire where justice and valor would prevail\n\n'

# %% [markdown]
# ## **Stemming (3 marks)**
#    a. Apply stemming to the words in the story.
#    b. Provide a few examples of stemmed words.

# %%
#importing nltk's porter stemmer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()

def stem_words(txt):
  word_tokens = word_tokenize(txt)
  stems = [stemmer.stem(word) for word in word_tokens]
  return stems

print(stem_words(text))
# Out:
# ['in', 'the', 'rug', 'terrain', 'of', 'the', 'western', 'ghat', ',', 'shivaji', 'maharaj', ',', 'the', 'founder', 'of', 'the', 'maratha', 'empir', ',', 'wa', 'prepar', 'for', 'anoth', 'day', 'of', 'strateg', 'plan', 'and', 'militari', 'campaign', '.', 'known', 'for', 'hi', 'innov', 'tactic', 'and', 'leadership', ',', 'shivaji', 'maharaj', 'wa', 'determin', 'to', 'strengthen', 'hi', 'kingdom', 'and', 'protect', 'hi', 'peopl', 'from', 'extern', 'threat', '.', 'shivaji', 'maharaj', '’', 's', 'stronghold', 'wa', 'the', 'raigad', 'fort', ',', 'a', 'formid', 'fortress', 'perch', 'high', 'on', 'a', 'hilltop', '.', 'the', 'fort', "'s", 'strateg', 'locat', 'allow', 'him', 'to', 'overse', 'the', 'surround', 'land', 'and', 'defend', 'against', 'invad', '.', 'hi', 'trust', 'advisor', 'and', 'gener', 'would', 'gather', 'in', 'the', 'fort', "'s", 'grand', 'hall', 'to', 'discuss', 'plan', ',', 'share', 'intellig', ',', 'and', 'make', 'critic', 'decis', 'for', 'the', 'empir', "'s", 'expans', '.', 'the', 'even', 'in', 'shivaji', 'maharaj', "'s", 'court', 'were', 'vibrant', 'with', 'activ', '.', 'he', 'would', 'host', 'feast', 'and', 'gather', 'to', 'bolster', 'the', 'moral', 'of', 'hi', 'soldier', 'and', 'celebr', 'victori', '.', 'dure', 'these', 'event', ',', 'shivaji', 'maharaj', 'would', 'address', 'hi', 'peopl', ',', 'share', 'hi', 'vision', 'for', 'a', 'prosper', 'and', 'unit', 'maratha', 'empir', '.', 'hi', 'leadership', 'inspir', 'loyalti', 'and', 'courag', 'among', 'hi', 'subject', '.', 'as', 'night', 'fell', ',', 'shivaji', 'maharaj', 'would', 'retir', 'to', 'hi', 'quarter', ',', 'reflect', 'on', 'the', 'day', "'s", 'achiev', 'and', 'prepar', 'for', 'the', 'challeng', 'ahead', '.', 'hi', 'dream', 'were', 'fill', 'with', 'vision', 'of', 'a', 'strong', 'and', 'resili', 'empir', ',', 'where', 'justic', 'and', 'valor', 'would', 'prevail', '.']

# %% [markdown]
# ## **Lemmatization (3 marks)**
#    a. Apply lemmatization to the words in the story.
#    b. Provide a few examples of lemmatized words.

# %%
from nltk.stem import wordnet
from nltk.tokenize import word_tokenize

# %%
def lemmatize_word(txt):
    nltk.download('wordnet')
    word_tokens = word_tokenize(txt)
    lemmas = [wordnet.WordNetLemmatizer().lemmatize(word, pos='v') for word in word_tokens]
    return lemmas

print(lemmatize_word(text))
# Out:
# ['In', 'the', 'rugged', 'terrain', 'of', 'the', 'Western', 'Ghats', ',', 'Shivaji', 'Maharaj', ',', 'the', 'founder', 'of', 'the', 'Maratha', 'Empire', ',', 'be', 'prepare', 'for', 'another', 'day', 'of', 'strategic', 'plan', 'and', 'military', 'campaign', '.', 'Known', 'for', 'his', 'innovative', 'tactics', 'and', 'leadership', ',', 'Shivaji', 'Maharaj', 'be', 'determine', 'to', 'strengthen', 'his', 'kingdom', 'and', 'protect', 'his', 'people', 'from', 'external', 'threats', '.', 'Shivaji', 'Maharaj', '’', 's', 'stronghold', 'be', 'the', 'Raigad', 'Fort', ',', 'a', 'formidable', 'fortress', 'perch', 'high', 'on', 'a', 'hilltop', '.', 'The', 'fort', "'s", 'strategic', 'location', 'allow', 'him', 'to', 'oversee', 'the', 'surround', 'land', 'and', 'defend', 'against', 'invaders', '.', 'His', 'trust', 'advisors', 'and', 'general', 'would', 'gather', 'in', 'the', 'fort', "'s", 'grand', 'hall', 'to', 'discuss', 'plan', ',', 'share', 'intelligence', ',', 'and', 'make', 'critical', 'decisions', 'for', 'the', 'empire', "'s", 'expansion', '.', 'The', 'even', 'in', 'Shivaji', 'Maharaj', "'s", 'court', 'be', 'vibrant', 'with', 'activity', '.', 'He', 'would', 'host', 'feast', 'and', 'gather', 'to', 'bolster', 'the', 'morale', 'of', 'his', 'soldier', 'and', 'celebrate', 'victories', '.', 'During', 'these', 'events', ',', 'Shivaji', 'Maharaj', 'would', 'address', 'his', 'people', ',', 'share', 'his', 'vision', 'for', 'a', 'prosperous', 'and', 'unite', 'Maratha', 'Empire', '.', 'His', 'leadership', 'inspire', 'loyalty', 'and', 'courage', 'among', 'his', 'subject', '.', 'As', 'night', 'fell', ',', 'Shivaji', 'Maharaj', 'would', 'retire', 'to', 'his', 'quarter', ',', 'reflect', 'on', 'the', 'day', "'s", 'achievements', 'and', 'prepare', 'for', 'the', 'challenge', 'ahead', '.', 'His', 'dream', 'be', 'fill', 'with', 'visions', 'of', 'a', 'strong', 'and', 'resilient', 'empire', ',', 'where', 'justice', 'and', 'valor', 'would', 'prevail', '.']
# [nltk_data] Downloading package wordnet to /home/shiv/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## **Named Entity Recognition (NER) (3 marks)**
#    Identify and list all named entities (e.g., people, locations) in the story.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag, ne_chunk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')

def ner(txt):
    word_tokens = word_tokenize(txt)
    word_pos = pos_tag(word_tokens)
    named_entities = ne_chunk(word_pos)
    return named_entities

named_entities = ner(text)

print(named_entities)
# Out:
# [nltk_data] Downloading package punkt to /home/shiv/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/shiv/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/shiv/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/shiv/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# (S
#   (PERSON Brain/NNP)
#   (PERSON Lara/NNP)
#   scored/VBD
#   the/DT
#   highest/JJS
#   400/CD
#   runs/NNS
#   in/IN
#   a/DT
#   test/NN
#   match/NN
#   which/WDT
#   played/VBD
#   in/IN
#   between/IN
#   (ORGANIZATION WI/NNP)
#   and/CC
#   (GPE England/NNP)
#   ./.)

# %% [markdown]
# ## **Part-of-Speech Tagging (3 marks)**
#    Tag each word in the story with its corresponding part of speech. Provide the tagged text for a few sentences.

# %%
from nltk import pos_tag

def pos_tagg(text):
    word_tokens = word_tokenize(text)
    return pos_tag(word_tokens)

pos_tagg(text)
# Out:
# [('Brain', 'NNP'),
#  ('Lara', 'NNP'),
#  ('scored', 'VBD'),
#  ('the', 'DT'),
#  ('highest', 'JJS'),
#  ('400', 'CD'),
#  ('runs', 'NNS'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('test', 'NN'),
#  ('match', 'NN'),
#  ('which', 'WDT'),
#  ('played', 'VBD'),
#  ('in', 'IN'),
#  ('between', 'IN'),
#  ('WI', 'NNP'),
#  ('and', 'CC'),
#  ('England', 'NNP'),
#  ('.', '.')]

# %% [markdown]
# ## **Term Frequency (2 marks)**
#    Calculate the term frequency (TF) of the word "Shivaji" in the story.

# %%
from nltk.tokenize import word_tokenize
from collections import Counter
import nltk

nltk.download('punkt')

text = """
In the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns. Known for his innovative tactics and leadership, Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats.

Shivaji Maharaj’s stronghold was the Raigad Fort, a formidable fortress perched high on a hilltop. The fort's strategic location allowed him to oversee the surrounding lands and defend against invaders. His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.

The evenings in Shivaji Maharaj's court were vibrant with activity. He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories. During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire. His leadership inspired loyalty and courage among his subjects.

As night fell, Shivaji Maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead. His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.
"""

word_tokens = word_tokenize(text)

word_tokens_lower = [word.lower() for word in word_tokens]

total_words = len(word_tokens_lower)

word_counts = Counter(word_tokens_lower)

tf_shivaji = word_counts["shivaji"] / total_words

print(f"Term Frequency (TF) of 'Shivaji': {tf_shivaji:.6f}")
# Out:
# Term Frequency (TF) of 'Shivaji': 0.026432
# [nltk_data] Downloading package punkt to /home/shiv/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## **Frequency Distribution (3 marks)**
# Plot the frequency distribution of the top 10 most common words in the story. Describe the results.

# %%
import matplotlib.pyplot as plt
from nltk.probability import FreqDist

word_tokens = word_tokenize(text.lower())

fdist = FreqDist(word_tokens)

fdist.plot(10, title="Top 10 Most Common Words")
# Out:
# <Axes: title={'center': 'Top 10 Most Common Words'}, xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## **Token Count (2 marks)**
# Count the total number of tokens (words) in the story.

# %%
word_tokens = word_tokenize(text)

total_tokens = len(word_tokens)
print(f"Total number of tokens: {total_tokens}")
# Out:
# Total number of tokens: 227

# %% [markdown]
# ## **Sentence Count (2 marks)**
# Count the total number of sentences in the story.

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(text)
total_sentences = len(sentences)
print(f"Total number of sentences: {total_sentences}")
# Out:
# Total number of sentences: 11

# %% [markdown]
# ## **Stopword Frequency (2 marks)**
# Calculate the frequency of stopwords in the story. Provide the top 3 most frequent stopwords.

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(text.lower())

stopword_counts = Counter([word for word in word_tokens if word in stop_words])
top_3_stopwords = stopword_counts.most_common(3)

print(f"Top 3 most frequent stopwords: {top_3_stopwords}")
# Out:
# Top 3 most frequent stopwords: [('the', 13), ('and', 13), ('his', 11)]
# [nltk_data] Downloading package stopwords to /home/shiv/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## **Longest Word (2 marks)**
# Identify the longest word in the story and its length.

# %%
longest_word = max(word_tokens, key=len)
print(f"Longest word: {longest_word}, Length: {len(longest_word)}")
# Out:
# Longest word: intelligence, Length: 12

# %% [markdown]
# ## **Word Cloud (3 marks)**
# Create a word cloud based on the story. Describe the most prominent words in the cloud.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Noun Identification (2 marks)**
# Identify and list all nouns in the story.

# %%
from nltk import pos_tag

pos_tags = pos_tag(word_tokenize(text))

nouns = [word for word, pos in pos_tags if pos.startswith('NN')]
print(f"Nouns: {nouns}")
# Out:
# Nouns: ['terrain', 'Ghats', 'Shivaji', 'Maharaj', 'founder', 'Maratha', 'Empire', 'day', 'planning', 'campaigns', 'tactics', 'leadership', 'Shivaji', 'Maharaj', 'kingdom', 'people', 'threats', 'Shivaji', 'Maharaj', '’', 'stronghold', 'Raigad', 'Fort', 'fortress', 'hilltop', 'fort', 'location', 'lands', 'invaders', 'advisors', 'generals', 'fort', 'hall', 'plans', 'share', 'intelligence', 'decisions', 'empire', 'expansion', 'evenings', 'Shivaji', 'Maharaj', 'court', 'activity', 'feasts', 'gatherings', 'morale', 'soldiers', 'celebrate', 'victories', 'events', 'Shivaji', 'Maharaj', 'people', 'vision', 'Maratha', 'Empire', 'leadership', 'loyalty', 'courage', 'subjects', 'night', 'Shivaji', 'Maharaj', 'quarters', 'day', 'achievements', 'challenges', 'dreams', 'visions', 'empire', 'justice', 'valor']

# %% [markdown]
# ## **Verb Identification (2 marks)**
#  Identify and list all verbs in the story.

# %%
verbs = [word for word, pos in pos_tags if pos.startswith('VB')]
print(f"Verbs: {verbs}")
# Out:
# Verbs: ['was', 'preparing', 'Known', 'was', 'determined', 'strengthen', 'protect', 's', 'was', 'perched', 'allowed', 'oversee', 'surrounding', 'defend', 'gather', 'discuss', 'make', 'were', 'host', 'bolster', 'address', 'sharing', 'inspired', 'fell', 'retire', 'reflecting', 'preparing', 'were', 'filled', 'prevail']

# %% [markdown]
# ## **Word Context (2 marks)**
# Find and list the sentences where the word "empire" appears.

# %%
sentences_with_empire = [sentence for sentence in sentences if "empire" in sentence.lower()]
print(f"Sentences with 'empire': {sentences_with_empire}")
# Out:
# Sentences with 'empire': ['\nIn the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns.', "His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.", 'During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire.', 'His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.']

# %% [markdown]
# ## **Named Entity Categorization (2 marks)**
# Categorize the identified named entities into people, locations, and organizations.

# %%
from nltk import ne_chunk

# Perform named entity recognition
named_entities = ne_chunk(pos_tag(word_tokenize(text)))

# Categorize named entities into people, locations, and organizations
people = []
locations = []
organizations = []

for chunk in named_entities:
    if hasattr(chunk, 'label'):
        entity_name = ' '.join(c[0] for c in chunk)
        entity_type = chunk.label()
        if entity_type == 'PERSON':
            people.append(entity_name)
        elif entity_type == 'GPE':
            locations.append(entity_name)
        elif entity_type == 'ORGANIZATION':
            organizations.append(entity_name)

print(f"People: {people}")
print(f"Locations: {locations}")
print(f"Organizations: {organizations}")
# Out:
# People: ['Shivaji Maharaj', 'Shivaji Maharaj', 'Shivaji Maharaj', 'Shivaji Maharaj', 'Maratha Empire', 'Shivaji Maharaj']
# Locations: ['Shivaji Maharaj']
# Organizations: ['Maratha Empire', 'Raigad Fort']

# %% [markdown]
# ## **Word Frequency Comparison (2 marks)**
# Compare the frequency of the words "kingdom" and "feast" in the story. Provide their counts and analyze the difference.

# %%
# Calculate the frequency of the words "kingdom" and "feast"
kingdom_count = word_tokens_lower.count("kingdom")
feast_count = word_tokens_lower.count("feast")

print(f"Frequency of 'kingdom': {kingdom_count}")
print(f"Frequency of 'feast': {feast_count}")
print(f"Difference: {kingdom_count - feast_count}")
# Out:
# Frequency of 'kingdom': 1
# Frequency of 'feast': 0
# Difference: 1
